# %%
import pandas as pd
import pulp
import re
from rapidfuzz import process, fuzz
import csv

# %%
df = pd.read_csv('/home/dutchr/python_code/scripts/parent_camp_info/camp_info/Year 10 Outdoor Experience 2025 - Group Selection Form (Responses).csv').astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     107 non-null    object
#  1   Email address                 107 non-null    object
#  2   Your First Name               107 non-null    object
#  3   Your Surname                  107 non-null    object
#  4   Choice 1 (First and Surname)  107 non-null    object
#  5   Choice 2 (First and Surname)  107 non-null    object
#  6   Choice 3 (First and Surname)  107 non-null    object
#  7   Choice 4 (First and Surname)  107 non-null    object
#  8   Choice 5 (First and Surname)  107 non-null    object
# dtypes: object(9)
# memory usage: 7.7+ KB

# %%
def clean_text(text):
    """
    Converts text to lowercase, strips leading/trailing whitespace,
    and replaces multiple whitespaces with a single space.
    """
    text = text.title().strip()
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text

# %%
student_preferences = {}
for index, row in df.iterrows():
    # Combine the first name and surname into a full name key
    full_name = f"{row['Your First Name']} {row['Your Surname']}".title().strip()
    # Collect all group choices into a list
    preferences = [
        clean_text(row['Choice 1 (First and Surname)']),
        clean_text(row['Choice 2 (First and Surname)']),
        clean_text(row['Choice 3 (First and Surname)']),
        clean_text(row['Choice 4 (First and Surname)']),
        clean_text(row['Choice 5 (First and Surname)'])
    ]
    preferences = [pref for pref in preferences if pref not in ('nan', '', 'Nan')]
    # Assign the list of preferences to the dictionary under the full name key
    student_preferences[full_name] = preferences

# %%
def correct_names(preferences, main_students):
    # Dictionary to store corrected preferences
    corrected_preferences = {}
    
    # Iterate through each student and their preferences
    for student, prefs in preferences.items():
        corrected_prefs = []
        for pref in prefs:
            # Find the best match for the misspelt name in the main_students list
            best_match = process.extractOne(pref, main_students, scorer=fuzz.WRatio)
            if best_match and best_match[1] > 80:  # You can adjust the threshold score
                corrected_prefs.append(best_match[0])
            else:
                corrected_prefs.append(pref)  # If no good match, keep the original
        corrected_preferences[student] = corrected_prefs
    
    return corrected_preferences

# %%
main_students = set(student_preferences.keys())

corrected_preferences = correct_names(student_preferences, main_students)

# %%
# Check if there are any students who are in preferences but not in the main student list
# Gather all preferences into a single set
all_preferences = set()
for preferences in corrected_preferences.values():
    all_preferences.update(preferences)

# Students who are in preferences but not in the main student list
students_only_in_preferences = all_preferences - main_students

students_only_in_preferences

# %%
not_attending = pd.read_csv('/home/dutchr/python_code/scripts/parent_camp_info/tent_pairing/empty not attending.csv').astype('str')

# %%
not_attending = not_attending['Absent'].str.title().str.strip().tolist()

# %%
students_only_in_preferences = [student for student in students_only_in_preferences if student not in not_attending]

# %%
students_only_in_preferences.sort()
students_only_in_preferences
# Out:
# ['Alex Mathers',
#  'Amarinder Singh',
#  'Aria Ripley',
#  'Beau Hogarth',
#  'Beue Hogath',
#  'Charli Kleeman',
#  'Charlotte Nairn',
#  'Charlotte Narin',
#  'Connor Leverett',
#  'Emalia Basic',
#  'Hana Parry',
#  'Imogen Brown',
#  'Indiana Stacy',
#  'Leonidas Sioutus',
#  'Maddy Mckay',
#  'Madeline Weeks',
#  'Nick Kosmala',
#  'Oluwatimilehin Bamise',
#  'Shrays Butnagger',
#  'Sophie Arozollo',
#  'Sophie Arruzzolo',
#  'Sophie Aruzzolo',
#  'Timi Bamise',
#  'Tyson Soraghan',
#  'Venkata Kilari']

# %%
#remove students who are not attending from all preferences
for student, prefs in corrected_preferences.items():
    corrected_preferences[student] = [pref for pref in prefs if pref not in not_attending]

# %%
#add students_only_in_preferences to corrected_preferences dict as keys with empty lists as values
for student in students_only_in_preferences:
    corrected_preferences[student] = []

# %%
corrected_preferences
# Out:
# {'Elani  Stevens': ['Lily  Brain',
#   'Alexia Moraitis',
#   'Chanel Surace',
#   'Kasia Nagy',
#   'Imogen Brown'],
#  'Grace Terrington': ['Jersi Jensen-Wallace',
#   'Ekam Jammu',
#   'Gurnaaz Kaur  Grewal'],
#  'Ekam Jammu': ['Grace Terrington', 'Jersi Jensen-Wallace', 'Ella Field'],
#  'Jersi Jensen-Wallace': ['Grace Terrington',
#   'Gurnaaz Kaur  Grewal',
#   'Ekam Jammu'],
#  'Krish Tewar': ['Ryan Fritsch',
#   'Gabriel Truscott',
#   'Bailey Clark',
#   'Joshua Doak',
#   'Kiano Colebrook'],
#  'Kiano Colebrook': ['Luke Mathers',
#   'Joshua Doak',
#   'Gabriel Truscott',
#   'Bailey Clark',
#   'Saxon Hall'],
#  'Aliza  Patterson': ['Ella  Forster', 'Tahlia Waanders', 'Emalia Basic'],
#  'Sienna Jaeschke': ['Indie Stacey',
#   'Taylah Ross',
#   'Sophia Chinca',
#   'Cara Twigge',
#   'Annalee Loechel'],
#  'Luke Mathers': ['Kiano Colebrook',
#   'Cameron Harrald',
#   'Joshua Doak',
#   'Bailey Clark',
#   'Zoe Parcell'],
#  'Xavier Trusz': ['Owen Doyle',
#   'Daniel Cox',
#   'Nicolas Dinevski',
#   'Oluwatimilehin Bamise'],
#  'Owen Doyle': ['Xavier Trusz',
#   'Daniel Cox',
#   'Harry Mccarthur',
#   'Timi Bamise',
#   'Nicolas Dinevski'],
#  'Shreyas Bhatnagar': ['Armaan Natarajan',
#   'Mehar Seth',
#   'Tejveer Sekhon',
#   'Venkata Kilari',
#   'Amarinder Singh'],
#  'Kate Potuszynski': ['Milla  Schmidt',
#   'Olivia Williams',
#   'Aria Ripley',
#   'Charlotte Gao',
#   'Gurnaaz Kaur  Grewal'],
#  'Harry Tamblyn': ['Jonah Podlewski',
#   'Connor Lengs',
#   'Krishna  Neelam',
#   'Ashton  Fenn',
#   'Jake  Do'],
#  'Isabelle Bennett': ['Ella  Forster',
#   'Tahlia Waanders',
#   'Madison Mckay',
#   'Aliza  Patterson',
#   'Hannah  Thompson'],
#  'Jenish Pathak': ['Henry Hajek',
#   'Tejveer Sekhon',
#   'Joshua Lam-Huynh',
#   'Dherya Chousalkar'],
#  'Charlotte Gao': ['Olivia Williams', 'Milla  Schmidt', 'Kate Potuszynski'],
#  'Valentina  Vargas Zuluaga': ['Annalee Loechel',
#   'Sophie Arozollo',
#   'Jake  Do',
#   'Jake  Do',
#   'Jake  Do'],
#  'Joshua Doak': ['Tyson Soraghan',
#   'Kiano Colebrook',
#   'Bailey Clark',
#   'Krish Tewar',
#   'Luke Mathers'],
#  'Ryan Fritsch': ['Henry Hajek',
#   'Cameron Harrald',
#   'Luke Mathers',
#   'Beau Hogarth',
#   'Alex Mathers'],
#  'Nicholas Walker': ['Oluwatimilehin Bamise',
#   'Zac Stint',
#   'Daniel Cox',
#   'Nicolas Dinevski',
#   'Xavier Trusz'],
#  'Jonah Podlewski': ['Harry Tamblyn',
#   'Jake  Do',
#   'Connor Lengs',
#   'Harry Mccarthur',
#   'Nicholas  Kosmala'],
#  'Chanel Surace': ['Alexia Moraitis',
#   'Imi  Brown',
#   'Lily  Brain',
#   'Elani  Stevens',
#   'Kasia Nagy'],
#  'Ashton  Fenn': ['Connor Lengs',
#   'Harry Tamblyn',
#   'Nectarios Georgiou',
#   'Nicholas  Kosmala',
#   'Jake  Do'],
#  'Connor Lengs': ['Ashton  Fenn',
#   'Harry Tamblyn',
#   'Nectarios Georgiou',
#   'Andrzej Czechuara',
#   'Hiphrany  Chung'],
#  'Elly-May Battersby': ['Sophie Arruzzolo',
#   'Ella Pring',
#   'Ariana Loizou',
#   'Peyton Shaw',
#   'Samaira  Bath'],
#  'Noah Garcia': ['Gabriel Truscott',
#   'Kiano Colebrook',
#   'Ryan Fritsch',
#   'Bailey Clark',
#   'Joshua Doak'],
#  'Elijah Cockburn': ['Dylan Rands',
#   'Vincent Swiatczak',
#   'Krishna  Neelam',
#   'Hridya  Soni'],
#  'Peyton Shaw': ['Samaira  Bath',
#   'Ariana Loizou',
#   'Ella Pring',
#   'Elly-May Battersby',
#   'Sophie Arruzzolo'],
#  'Lucy   Haberfield': ['Ariana Loizou', 'Peyton Shaw'],
#  'Imi  Brown': ['Alexia Moraitis',
#   'Chanel Surace',
#   'Kasia Nagy',
#   'Lily  Brain',
#   'Charli Kleeman'],
#  'Ella  Forster': ['Aliza  Patterson',
#   'Tahlia Waanders',
#   'Madison Mckay',
#   'Isabelle Bennett',
#   'Hannah  Thompson'],
#  'Hannah Ingerson': ['Sienna  Gunn',
#   'Natalie Hoffman',
#   'Valentina  Vargas Zuluaga',
#   'Sophia Chinca',
#   'Ebony Crowe'],
#  'Tahlia Waanders': ['Madison Mckay',
#   'Isabelle Bennett',
#   'Ella  Forster',
#   'Aliza  Patterson',
#   'Grace Watts'],
#  'Kasia Nagy': ['Chanel Surace',
#   'Lily  Brain',
#   'Alexia Moraitis',
#   'Imogen Brown',
#   'Elani  Stevens'],
#  'Andrzej Czechuara': ['Nectarios Georgiou',
#   'Zade Bader',
#   'Ashton  Fenn',
#   'Connor Lengs',
#   'Nick Kosmala'],
#  'Olivia Williams': ['Mehar  Chadha',
#   'Milla  Schmidt',
#   'Charlotte Gao',
#   'Cara Twigge',
#   'Kate Potuszynski'],
#  'Zara Lebessis': ['Zara Walding',
#   'Grace Watts',
#   'Isabella Winder',
#   'Tahlia Waanders',
#   'Maddy Mckay'],
#  'Alexia Moraitis': ['Lily  Brain',
#   'Imi  Brown',
#   'Chanel Surace',
#   'Elani  Stevens',
#   'Kasia Nagy'],
#  'Lily  Brain': ['Alexia Moraitis',
#   'Elani  Stevens',
#   'Chanel Surace',
#   'Kasia Nagy',
#   'Imi  Brown'],
#  'Ruby  Dolejs': ['Ella Field', 'Lily Drechsler', 'Lucy   Haberfield'],
#  'Nicolas Dinevski': ['Harry Mccarthur',
#   'Owen Doyle',
#   'Xavier Trusz',
#   'Oluwatimilehin Bamise',
#   'Daniel Cox'],
#  'Ariana Loizou': ['Lucy   Haberfield',
#   'Elly-May Battersby',
#   'Sophie Arruzzolo',
#   'Peyton Shaw',
#   'Samaira  Bath'],
#  'Samaira  Bath': ['Peyton Shaw',
#   'Ariana Loizou',
#   'Lucy   Haberfield',
#   'Ella Pring',
#   'Elly-May Battersby'],
#  'Gurnaaz Kaur  Grewal': ['Jersi Jensen-Wallace',
#   'Grace Terrington',
#   'Ekam Jammu'],
#  'Samantha Pengilly': ['Annalee Loechel',
#   'Indie Stacey',
#   'Taylah Ross',
#   'Cara Twigge',
#   'Sophia Chinca'],
#  'Alexis Corbin': ['Ruby  Dolejs',
#   'Hannah  Thompson',
#   'Ella Field',
#   'Lily Drechsler',
#   'Isabella Winder'],
#  'Hiphrany  Chung': ['Hoai Huynh',
#   'Nicholas  Kosmala',
#   'Connor Lengs',
#   'Daniel Cox',
#   'Oluwatimilehin Bamise'],
#  'Ella Field': ['Lily Drechsler', 'Ebony Crowe'],
#  'Gabriel Truscott': ['Harry  Cox',
#   'Saxon Hall',
#   'Bailey Clark',
#   'Noah Garcia',
#   'Joshua Doak'],
#  'Lily Drechsler': ['Ella Field', 'Ebony Crowe', 'Hanna  Abimosleh'],
#  'Cooper Bache': ['Luke Schulz', 'Jordan  Zollo', 'Beau Hogarth'],
#  'Hoai Huynh': ['Hiphrany  Chung',
#   'Jake  Do',
#   'Nicholas  Kosmala',
#   'Zade Bader',
#   'Jonah Podlewski'],
#  'Madison Mckay': ['Tahlia Waanders',
#   'Isabelle Bennett',
#   'Ella  Forster',
#   'Aliza  Patterson',
#   'Hannah  Thompson'],
#  'Dherya Chousalkar': ['Armaan Natarajan',
#   'Darsh Patel',
#   'Mehar Seth',
#   'Tejveer Sekhon',
#   'Jaival Sheth'],
#  'Cara Twigge': ['Indiana Stacy',
#   'Charlotte Nairn',
#   'Olivia Williams',
#   'Taylah Ross',
#   'Annalee Loechel'],
#  'Hannah  Thompson': ['Tahlia Waanders',
#   'Madison Mckay',
#   'Ella  Forster',
#   'Aliza  Patterson',
#   'Isabelle Bennett'],
#  'Harry  Cox': ['Saxon Hall',
#   'Alex Mathers',
#   'Samuel Pollock',
#   'Ryan Fritsch'],
#  'Zara Walding': ['Grace Watts', 'Isabella Winder', 'Zara Lebessis'],
#  'Bailey Clark': ['Kiano Colebrook',
#   'Joshua Doak',
#   'Gabriel Truscott',
#   'Luke Mathers'],
#  'Zoe Parcell': ['Natalie Hoffman',
#   'Annalee Loechel',
#   'Sophia Chinca',
#   'Sienna  Gunn',
#   'Cara Twigge'],
#  'Annalee Loechel': ['Valentina  Vargas Zuluaga',
#   'Aria Ripley',
#   'Zoe Parcell',
#   'Samantha Pengilly',
#   'Indie Stacey'],
#  'Milla  Schmidt': ['Charlotte Gao',
#   'Annalee Loechel',
#   'Zoe Parcell',
#   'Kate Potuszynski',
#   'Olivia Williams'],
#  'Armaan Natarajan': ['Shreyas Bhatnagar',
#   'Dherya Chousalkar',
#   'Darsh Patel',
#   'Mehar Seth',
#   'Tejveer Sekhon'],
#  'Scarlett Brodde': ['Hana Parry', 'Sienna  Gunn', 'Charli Kleeman'],
#  'Tejveer Sekhon': ['Mehar Seth',
#   'Dherya Chousalkar',
#   'Armaan Natarajan',
#   'Darsh Patel',
#   'Shreyas Bhatnagar'],
#  'Hridya  Soni': ['Krishna  Neelam',
#   'Vincent Swiatczak',
#   'Tyson Soraghan',
#   'Luke Schulz',
#   'Jordan  Zollo'],
#  'Harry Mccarthur': ['Nicolas Dinevski',
#   'Owen Doyle',
#   'Xavier Trusz',
#   'Jonah Podlewski',
#   'Daniel Cox'],
#  'Grace Watts': ['Zara Walding', 'Zara Lebessis', 'Isabella Winder'],
#  'Zade Bader': ['Andrzej Czechuara',
#   'Nectarios Georgiou',
#   'Jonah Podlewski',
#   'Hoai Huynh',
#   'Nicholas  Kosmala'],
#  'Nectarios Georgiou': ['Andrzej Czechuara',
#   'Harry Tamblyn',
#   'Ashton  Fenn',
#   'Connor Lengs',
#   'Jake  Do'],
#  'Jaival Sheth': ['Darsh Patel',
#   'Mehar Seth',
#   'Dherya Chousalkar',
#   'Jordan  Zollo',
#   'Shreyas Bhatnagar'],
#  'Ella Pring': ['Elly-May Battersby',
#   'Sophie Arruzzolo',
#   'Lucy   Haberfield',
#   'Peyton Shaw',
#   'Ariana Loizou'],
#  'Mehar Seth': ['Tejveer Sekhon',
#   'Dherya Chousalkar',
#   'Darsh Patel',
#   'Jaival Sheth',
#   'Armaan Natarajan'],
#  'Naavi Chheoum': ['Zac Stint',
#   'Nicholas Walker',
#   'Daniel Cox',
#   'Xavier Trusz'],
#  'Zac Stint': ['Nicholas Walker',
#   'Naavi Chheoum',
#   'Owen Doyle',
#   'Oluwatimilehin Bamise',
#   'Nicolas Dinevski'],
#  'Cameron Harrald': ['Ryan Fritsch',
#   'Saxon Hall',
#   'Henry Hajek',
#   'Beau Hogarth',
#   'Luke Mathers'],
#  'Guneet Kaur': ['Ebony Crowe',
#   'Hana Parry',
#   'Alexis Corbin',
#   'Annalee Loechel',
#   'Madeline Weeks'],
#  'Harrison  Connelly': ['William  Mayne',
#   'Tejveer Sekhon',
#   'Joshua Lam-Huynh',
#   'Leonidas Sioutus',
#   'Darsh Patel'],
#  'Jake  Do': ['Hoai Huynh',
#   'Nick Kosmala',
#   'Hiphrany  Chung',
#   'Jonah Podlewski',
#   'Connor Lengs'],
#  'Vincent Swiatczak': ['Krishna  Neelam',
#   'Hridya  Soni',
#   'Tyson Soraghan',
#   'Elijah Cockburn',
#   'Dylan Rands'],
#  'Leo Sioutis': ['Armaan Natarajan',
#   'Harrison  Connelly',
#   'Joshua Lam-Huynh',
#   'Olivia Williams',
#   'Henry Hajek'],
#  'Fena Rakholiya': ['Charlotte Narin',
#   'Samantha Pengilly',
#   'Indiana Stacy',
#   'Sophia Chinca'],
#  'Taylah Ross': ['Indie Stacey',
#   'Sienna Jaeschke',
#   'Samantha Pengilly',
#   'Annalee Loechel',
#   'Sophia Chinca'],
#  'Vaishnavi Rajesh': ['Charlotte Nairn',
#   'Fena Rakholiya',
#   'Samantha Pengilly',
#   'Annalee Loechel',
#   'Indie Stacey'],
#  'Darsh Patel': ['Jaival Sheth',
#   'Mehar Seth',
#   'Dherya Chousalkar',
#   'Armaan Natarajan',
#   'Jenish Pathak'],
#  'Natalie Hoffman': ['Zoe Parcell', 'Hannah Ingerson', 'Sienna  Gunn'],
#  'Mehar  Chadha': ['Olivia Williams',
#   'Aria Ripley',
#   'Annalee Loechel',
#   'Kate Potuszynski',
#   'Milla  Schmidt'],
#  'Isabella Winder': ['Zara Walding', 'Zara Lebessis', 'Grace Watts'],
#  'Hanna  Abimosleh': ['Ebony Crowe',
#   'Charlotte Nairn',
#   'Lily Drechsler',
#   'Madeline Weeks',
#   'Ella Field'],
#  'Jordan  Zollo': ['Cooper Bache',
#   'Hridya  Soni',
#   'Dylan Rands',
#   'Shrays Butnagger',
#   'Vincent Swiatczak'],
#  'Ebony Crowe': ['Guneet Kaur',
#   'Ella Field',
#   'Lily Drechsler',
#   'Hanna  Abimosleh',
#   'Ruby  Dolejs'],
#  'Samuel Pollock': ['Harry  Cox',
#   'Beau Hogarth',
#   'Henry Hajek',
#   'Ryan Fritsch',
#   'Jordan  Zollo'],
#  'Indie Stacey': ['Taylah Ross',
#   'Annalee Loechel',
#   'Cara Twigge',
#   'Sophia Chinca',
#   'Samantha Pengilly'],
#  'Sophia Chinca': ['Cara Twigge',
#   'Indie Stacey',
#   'Zoe Parcell',
#   'Taylah Ross',
#   'Charlotte Nairn'],
#  'Henry Hajek': ['Jenish Pathak',
#   'Beau Hogarth',
#   'Tejveer Sekhon',
#   'Cameron Harrald',
#   'Ryan Fritsch'],
#  'Nicholas  Kosmala': ['Zade Bader',
#   'Hoai Huynh',
#   'Jake  Do',
#   'Hiphrany  Chung',
#   'Jonah Podlewski'],
#  'Saxon Hall': ['Harry  Cox',
#   'Alex Mathers',
#   'Cameron Harrald',
#   'Kiano Colebrook',
#   'Gabriel Truscott'],
#  'Daniel Cox': ['Xavier Trusz', 'Owen Doyle', 'Timi Bamise'],
#  'Luke Schulz': ['Jordan  Zollo',
#   'Hridya  Soni',
#   'Connor Leverett',
#   'Daniel Cox',
#   'Harry Tamblyn'],
#  'Krishna  Neelam': ['Vincent Swiatczak',
#   'Hridya  Soni',
#   'Elijah Cockburn',
#   'Dylan Rands',
#   'Tyson Soraghan'],
#  'Dylan Rands': ['Elijah Cockburn',
#   'Vincent Swiatczak',
#   'Tyson Soraghan',
#   'Krishna  Neelam',
#   'Jordan  Zollo'],
#  'Alec Wallace': ['Joshua Lam-Huynh',
#   'Jenish Pathak',
#   'Henry Hajek',
#   'Beue Hogath'],
#  'Sienna  Gunn': ['Hannah Ingerson',
#   'Natalie Hoffman',
#   'Zoe Parcell',
#   'Scarlett Brodde',
#   'Hana Parry'],
#  'William  Mayne': ['Jenish Pathak',
#   'Joshua Lam-Huynh',
#   'Tejveer Sekhon',
#   'Henry Hajek'],
#  'Joshua Lam-Huynh': ['William  Mayne',
#   'Jenish Pathak',
#   'Darsh Patel',
#   'Armaan Natarajan',
#   'Alec Wallace'],
#  'Sake Demetri': ['Valentina  Vargas Zuluaga', 'Sophie Aruzzolo'],
#  'Alex Mathers': [],
#  'Amarinder Singh': [],
#  'Aria Ripley': [],
#  'Beau Hogarth': [],
#  'Beue Hogath': [],
#  'Charli Kleeman': [],
#  'Charlotte Nairn': [],
#  'Charlotte Narin': [],
#  'Connor Leverett': [],
#  'Emalia Basic': [],
#  'Hana Parry': [],
#  'Imogen Brown': [],
#  'Indiana Stacy': [],
#  'Leonidas Sioutus': [],
#  'Maddy Mckay': [],
#  'Madeline Weeks': [],
#  'Nick Kosmala': [],
#  'Oluwatimilehin Bamise': [],
#  'Shrays Butnagger': [],
#  'Sophie Arozollo': [],
#  'Sophie Arruzzolo': [],
#  'Sophie Aruzzolo': [],
#  'Timi Bamise': [],
#  'Tyson Soraghan': [],
#  'Venkata Kilari': []}

# %%
def solve_pairing(preferences):
    # Create a problem variable:
    prob = pulp.LpProblem("Student_Pairing", pulp.LpMaximize)

    # Create variables for each possible pair
    pairs = {}
    all_students = set(preferences.keys()) | set(pref for prefs in preferences.values() for pref in prefs)
    for student in all_students:
        for preferred in all_students:
            if student != preferred:  # Avoid pairing students with themselves
                pair_name = f"pair_{student}|{preferred}"
                pairs[(student, preferred)] = pulp.LpVariable(pair_name, 0, 1, pulp.LpBinary)

    # Objective function: maximize sum of mutual preferences
    prob += pulp.lpSum(pairs[(s, p)] * ((len(preferences[s]) +1 - preferences[s].index(p) if p in preferences[s] else 0.5) +
                                        (len(preferences[s]) +1 - preferences[p].index(s) if s in preferences[p] else 0.5))
                       for s in preferences for p in all_students if (s, p) in pairs)

    # Constraint: Each student can be in at most one pair
    for s in all_students:
        prob += pulp.lpSum(pairs[(s, p)] for p in all_students if (s, p) in pairs) + \
                pulp.lpSum(pairs[(p, s)] for p in all_students if (p, s) in pairs) <= 1

    # Solve the problem
    prob.solve()

    # Extract the pairs
    results = []
    seen = set()
    for (s, p), var in pairs.items():
        if pulp.value(var) == 1 and s not in seen and p not in seen:
            results.append((s, p))
            seen.update([s, p])

    return results

# %%
resulting_pairs = solve_pairing(corrected_preferences)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.10
# Build Date: Sep 26 2023
#
# command line - /home/dutchr/miniconda3/envs/school/lib/python3.13/site-packages/pulp/solverdir/cbc/linux/arm64/cbc /tmp/145a3221facf4ac29eb37ba77ff15228-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /tmp/145a3221facf4ac29eb37ba77ff15228-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 137 COLUMNS
# At line 86598 RHS
# At line 86731 BOUNDS
# At line 104024 ENDATA
# Problem MODEL has 132 rows, 17292 columns and 34584 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 550.5 - 0.01 seconds
# Cgl0004I processed model has 132 rows, 8646 columns (8646 integer (8646 of which binary)) and 17292 elements
# Cutoff increment increased from 1e-05 to 0.4999
# Cbc0038I Initial state - 12 integers unsatisfied sum - 6
# Cbc0038I Solution found of 502.5
# Cbc0038I Before mini branch and bound, 8634 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 132 rows 8646 columns, reduced to 12 rows 12 columns
# Cbc0038I Mini branch and bound improved solution from 502.5 to 539.5 (0.08 seconds)
# Cbc0038I Round again with cutoff of 541.05
# Cbc0038I Reduced cost fixing fixed 2223 variables on major pass 2
# Cbc0038I Pass   1: suminf.    0.84997 (3) obj. 541.05 iterations 121
# Cbc0038I Pass   2: suminf.    0.84997 (3) obj. 541.05 iterations 41
# Cbc0038I Pass   3: suminf.    0.96816 (3) obj. 541.05 iterations 67
# Cbc0038I Pass   4: suminf.    0.96816 (3) obj. 541.05 iterations 37
# Cbc0038I Pass   5: suminf.    0.84997 (3) obj. 541.05 iterations 59
# Cbc0038I Pass   6: suminf.    2.34997 (6) obj. 541.05 iterations 83
# Cbc0038I Pass   7: suminf.    0.51664 (3) obj. 541.05 iterations 57
# Cbc0038I Pass   8: suminf.    0.51664 (3) obj. 541.05 iterations 0
# Cbc0038I Pass   9: suminf.    0.69543 (3) obj. 541.05 iterations 65
# Cbc0038I Pass  10: suminf.    0.69543 (3) obj. 541.05 iterations 40
# Cbc0038I Pass  11: suminf.    0.51664 (3) obj. 541.05 iterations 62
# Cbc0038I Pass  12: suminf.    3.54991 (8) obj. 541.05 iterations 101
# Cbc0038I Pass  13: suminf.    0.12860 (2) obj. 541.05 iterations 103
# Cbc0038I Solution found of 541.5
# Cbc0038I Before mini branch and bound, 8622 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 132 rows 8646 columns, reduced to 20 rows 24 columns
# Cbc0038I Mini branch and bound improved solution from 541.5 to 545 (0.12 seconds)
# Cbc0038I Round again with cutoff of 546.5
# Cbc0038I Reduced cost fixing fixed 6587 variables on major pass 3
# Cbc0038I Pass  14: suminf.    2.99997 (6) obj. 546.5 iterations 13
# Cbc0038I Pass  15: suminf.    2.99996 (7) obj. 546.5 iterations 35
# Cbc0038I Pass  16: suminf.    2.99998 (6) obj. 546.5 iterations 71
# Cbc0038I Pass  17: suminf.    2.99998 (6) obj. 546.5 iterations 33
# Cbc0038I Pass  18: suminf.    2.99998 (6) obj. 546.5 iterations 1
# Cbc0038I Pass  19: suminf.    2.99997 (6) obj. 546.5 iterations 51
# Cbc0038I Pass  20: suminf.    2.99997 (6) obj. 546.5 iterations 40
# Cbc0038I Pass  21: suminf.    2.99998 (6) obj. 546.5 iterations 55
# Cbc0038I Pass  22: suminf.    3.59995 (9) obj. 546.5 iterations 84
# Cbc0038I Pass  23: suminf.    3.59995 (9) obj. 546.5 iterations 30
# Cbc0038I Pass  24: suminf.    3.59995 (9) obj. 546.5 iterations 0
# Cbc0038I Pass  25: suminf.    4.09089 (9) obj. 546.5 iterations 57
# Cbc0038I Pass  26: suminf.    3.99997 (9) obj. 546.5 iterations 43
# Cbc0038I Pass  27: suminf.    3.59995 (9) obj. 546.5 iterations 54
# Cbc0038I Pass  28: suminf.    3.59995 (9) obj. 546.5 iterations 28
# Cbc0038I Pass  29: suminf.    4.09089 (9) obj. 546.5 iterations 52
# Cbc0038I Pass  30: suminf.    3.00001 (7) obj. 546.5 iterations 52
# Cbc0038I Pass  31: suminf.    2.99998 (6) obj. 546.5 iterations 62
# Cbc0038I Pass  32: suminf.    2.99995 (6) obj. 546.5 iterations 50
# Cbc0038I Pass  33: suminf.    2.99995 (6) obj. 546.5 iterations 31
# Cbc0038I Pass  34: suminf.    2.99998 (6) obj. 546.5 iterations 69
# Cbc0038I Pass  35: suminf.    2.99998 (6) obj. 546.5 iterations 44
# Cbc0038I Pass  36: suminf.    2.99997 (6) obj. 546.5 iterations 7
# Cbc0038I Pass  37: suminf.    2.99995 (6) obj. 546.5 iterations 81
# Cbc0038I Pass  38: suminf.    2.99995 (6) obj. 546.5 iterations 35
# Cbc0038I Pass  39: suminf.    2.99998 (6) obj. 546.5 iterations 80
# Cbc0038I Pass  40: suminf.    2.99998 (6) obj. 546.5 iterations 43
# Cbc0038I Pass  41: suminf.    2.99997 (6) obj. 546.5 iterations 9
# Cbc0038I Pass  42: suminf.    2.99995 (6) obj. 546.5 iterations 75
# Cbc0038I Pass  43: suminf.    2.99995 (6) obj. 546.5 iterations 30
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 8628 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 132 rows 8646 columns, reduced to 14 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.20 seconds)
# Cbc0038I After 0.20 seconds - Feasibility pump exiting with objective of 545 - took 0.14 seconds
# Cbc0012I Integer solution of 545 found by feasibility pump after 0 iterations and 0 nodes (0.20 seconds)
# Cbc0038I Full problem 132 rows 8646 columns, reduced to 16 rows 18 columns
# Cbc0012I Integer solution of 548 found by DiveCoefficient after 7 iterations and 0 nodes (0.21 seconds)
# Cbc0031I 3 added rows had average density of 3
# Cbc0013I At root node, 3 cuts changed objective from 550.5 to 548 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 193 column cuts (193 active)  in 0.007 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 4 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 548, took 7 iterations and 0 nodes (0.22 seconds)
# Cbc0035I Maximum depth 0, 7193 variables fixed on reduced cost
# Cuts at root node changed objective from 550.5 to 548
# Probing was tried 2 times and created 193 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# Gomory was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 2 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                548.00000000
# Enumerated nodes:               0
# Total iterations:               7
# Time (CPU seconds):             0.19
# Time (Wallclock seconds):       0.22
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.22   (Wallclock seconds):       0.25

# %%
# Specify the filename
filename = "output_camp2.csv"

# Writing to the csv file
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Optionally write a header
    writer.writerow(['Name1', 'Name2'])
    # Write data
    writer.writerows(resulting_pairs)

print(f"Data successfully written to {filename}")

# %%
all_students = set(corrected_preferences.keys())

# %%
paired = set()
for first_name, second_name in resulting_pairs:
    paired.add(first_name)
    paired.add(second_name)

# %%
all_students - paired
# Out:
# set()

# %%
resulting_pairs
# Out:
# [('Nicholas  Kosmala', 'Zade Bader'),
#  ('Harrison  Connelly', 'Leo Sioutis'),
#  ('Madison Mckay', 'Hannah  Thompson'),
#  ('Fena Rakholiya', 'Charlotte Narin'),
#  ('Cameron Harrald', 'Ryan Fritsch'),
#  ('Alex Mathers', 'Imogen Brown'),
#  ('Harry Tamblyn', 'Jonah Podlewski'),
#  ('Andrzej Czechuara', 'Nectarios Georgiou'),
#  ('Joshua Lam-Huynh', 'William  Mayne'),
#  ('Cara Twigge', 'Indiana Stacy'),
#  ('Ella  Forster', 'Aliza  Patterson'),
#  ('Nicholas Walker', 'Oluwatimilehin Bamise'),
#  ('Dylan Rands', 'Elijah Cockburn'),
#  ('Ashton  Fenn', 'Connor Lengs'),
#  ('Hanna  Abimosleh', 'Madeline Weeks'),
#  ('Owen Doyle', 'Xavier Trusz'),
#  ('Sake Demetri', 'Sophie Aruzzolo'),
#  ('Hridya  Soni', 'Luke Schulz'),
#  ('Samaira  Bath', 'Peyton Shaw'),
#  ('Lily  Brain', 'Elani  Stevens'),
#  ('Jordan  Zollo', 'Cooper Bache'),
#  ('Grace Watts', 'Zara Walding'),
#  ('Alexis Corbin', 'Ruby  Dolejs'),
#  ('Ariana Loizou', 'Lucy   Haberfield'),
#  ('Shreyas Bhatnagar', 'Venkata Kilari'),
#  ('Jake  Do', 'Nick Kosmala'),
#  ('Vaishnavi Rajesh', 'Charlotte Nairn'),
#  ('Krish Tewar', 'Bailey Clark'),
#  ('Zoe Parcell', 'Natalie Hoffman'),
#  ('Scarlett Brodde', 'Hana Parry'),
#  ('Dherya Chousalkar', 'Armaan Natarajan'),
#  ('Harry Mccarthur', 'Nicolas Dinevski'),
#  ('Kiano Colebrook', 'Luke Mathers'),
#  ('Milla  Schmidt', 'Charlotte Gao'),
#  ('Vincent Swiatczak', 'Krishna  Neelam'),
#  ('Jersi Jensen-Wallace', 'Gurnaaz Kaur  Grewal'),
#  ('Alec Wallace', 'Beue Hogath'),
#  ('Samuel Pollock', 'Beau Hogarth'),
#  ('Mehar  Chadha', 'Olivia Williams'),
#  ('Jaival Sheth', 'Darsh Patel'),
#  ('Hiphrany  Chung', 'Hoai Huynh'),
#  ('Charli Kleeman', 'Sophie Arruzzolo'),
#  ('Ebony Crowe', 'Guneet Kaur'),
#  ('Valentina  Vargas Zuluaga', 'Sophie Arozollo'),
#  ('Henry Hajek', 'Jenish Pathak'),
#  ('Saxon Hall', 'Harry  Cox'),
#  ('Hannah Ingerson', 'Sienna  Gunn'),
#  ('Shrays Butnagger', 'Emalia Basic'),
#  ('Gabriel Truscott', 'Noah Garcia'),
#  ('Daniel Cox', 'Timi Bamise'),
#  ('Elly-May Battersby', 'Ella Pring'),
#  ('Kate Potuszynski', 'Aria Ripley'),
#  ('Indie Stacey', 'Sophia Chinca'),
#  ('Ekam Jammu', 'Grace Terrington'),
#  ('Zac Stint', 'Naavi Chheoum'),
#  ('Alexia Moraitis', 'Imi  Brown'),
#  ('Maddy Mckay', 'Leonidas Sioutus'),
#  ('Zara Lebessis', 'Isabella Winder'),
#  ('Mehar Seth', 'Tejveer Sekhon'),
#  ('Tahlia Waanders', 'Isabelle Bennett'),
#  ('Chanel Surace', 'Kasia Nagy'),
#  ('Annalee Loechel', 'Samantha Pengilly'),
#  ('Lily Drechsler', 'Ella Field'),
#  ('Amarinder Singh', 'Connor Leverett'),
#  ('Sienna Jaeschke', 'Taylah Ross'),
#  ('Joshua Doak', 'Tyson Soraghan')]
